# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaMaBueno/analysys-everpeak/blob/main/proyecto_aprobado_Sprint_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¡Hola Ana Maria! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# -------

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Ana Maria, tu trabajo refleja un manejo sólido de las herramientas de análisis de datos, desde la correcta carga y exploración inicial de los conjuntos hasta la limpieza y transformación cuidadosa de variables clave, lo que permite construir un análisis coherente y bien fundamentado. Se nota claridad en el uso de fechas, en la preparación de los datos para análisis temporal y en la aplicación de operaciones de agregación y visualización que ayudan a interpretar adecuadamente los patrones de movilidad y su relación con variables económicas, además de una buena capacidad para integrar resultados y extraer conclusiones razonadas.
#
# Como aspecto a mejorar, sería recomendable optimizar un poco el flujo del código evitando repeticiones innecesarias en procesos como la selección y unión de datasets, ya que esto no solo hace el notebook más claro y eficiente, sino que también facilita su mantenimiento y lectura.
#
# En definitiva, lograste un equilibrio perfecto entre habilidades técnicas, analíticas y estratégicas.
#
# Éxitos en tu próximo Sprint 🚀
#
# *Estado del Proyecto:* **Aprobado**
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco = pd.read_csv ('/datasets/oecd_city_economy.csv') #completa el código
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2616629911.py in <cell line: 0>()
#       1 # cargar archivos
# ----> 2 traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
#       3 eco = pd.read_csv ('/datasets/oecd_city_economy.csv') #completa el código
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/datasets/tomtom_traffic.csv'

# %%
# mostrar las primeras 5 filas de traffic
print(traffic.head(5))

# %%
# mostrar las primeras 5 filas de eco
print(eco.head(5))

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
#
# Has realizado correctamente la carga del conjunto de datos principal y has logrado visualizar de forma adecuada las primeras filas, lo cual demuestra una buena comprensión del uso de `read_csv` y `head` para exploración inicial.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Con respecto a la función `head`, es mejor no usarla dentro de un `print`, ya que esto hace que se pierdan las características de visualización de datos propias de los notebooks de Jupyter. En su lugar, puedes usar simplemente `df.head()`
#
# </div>
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
# Examinar la estructura de traffic
traffic.info()
traffic.head(3)

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTC` son de tipo object y deben ser datetime
# - JamsCount es ti po float64 y debe ser integer

# %%
# Examinar la estructura de eco
eco.info()
eco.head(3)

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita`, `Unemployment %`, PM2.5, population indican object y deben ser float
# - ...

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
#tu código aquí
traffic=traffic.rename(columns={"Country":"country",
                                "UpdateTimeUTC":"update_time_utc",
                                "UpdateTimeUTCWeekAgo":"update_time_utc_week_ago",
                                "City":"city","JamsDelay":"jams_delay",
                                "TrafficIndexLive":"traffic_index_live",
                                "JamsLengthInKms":"jams_length_in_kms",
                               "JamsCount":"jams_count",
                               "TrafficIndexWeekAgo":"traffic_index_week_ago",
                               "TravelTimeLivePer10KmsMins":"travel_time_live_per_10_kms_mins",
                                "TravelTimeHistoricPer10KmsMins":"travel_time_historic_per_10_kms_mins",
                                "MinsDelay":"mins_delay"

                               })
# verificar cambios
traffic.columns

# %%
# Estandarizar los nombres de las columnas de eco
#tu código aquí
eco=eco.rename(columns={"Country":"country","City GDP/capita":"city_gdp_capita","Population (M)":"population_m","City":"city","PM2.5 (μg/m³)":"pm","Unemployment %":"unemployment_pct","Year":"year"})
# verificar cambios



eco.columns

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has conseguido estandarizar de forma correcta y consistente los nombres de las columnas en ambos conjuntos de datos, lo cual es un paso clave para facilitar análisis posteriores y posibles uniones entre tablas.
#
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] =pd.to_datetime(traffic['update_time_utc'],errors="coerce") #tu código aquí
traffic['update_time_utc_week_ago'] =pd.to_datetime(traffic['update_time_utc_week_ago'],errors="coerce") #tu código aquí

# verificar el cambio

traffic.info()

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco['city_gdp_capita'] =(eco['city_gdp_capita']).astype(str).str.replace('.', '').str.replace(',', '.') .astype(float)

eco['unemployment_pct'] = (eco['unemployment_pct']).astype(str).str.replace('%',' ').str.replace (',','.').astype(float)

eco['population_m'] = (eco['population_m']).astype(str).str.replace(',', '.') .astype(float)



# Calcula la población total en unidades absolutas (Multiplica * 1000000)
eco['population_m'] =(eco
['population_m']*1000000)



# verificar el cambio
eco.info()

eco.head(3)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Ana Maria buen trabajo con la conversión de variables de fecha utilizando `pd.to_datetime`, lo cual es fundamental para análisis temporales y se nota una buena práctica al manejar errores con `coerce`. Además hiciste un trabajo cuidadoso en la limpieza y transformación de variables numéricas en el conjunto económico, resolviendo adecuadamente los separadores y porcentajes antes de convertir a tipo numérico.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
traffic['year'] = traffic["update_time_utc"].dt.year

# Verificar cambio
traffic.head(3)

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic[traffic['year']==2024].copy()

eco_2024 = eco[eco['year']==2024].copy()


# Revisar dataframes nuevos

display(traffic_2024.head())
display(eco_2024.head())

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
#
# Has conseguido extraer correctamente el año a partir de la variable de fecha, lo cual es un paso clave para segmentar la información temporalmente y se nota un buen dominio del acceso a atributos de fechas en pandas.
#
# El filtrado de los registros para el año 2024 está bien planteado y el uso de `.copy()` es una muy buena práctica para evitar efectos no deseados en los datos originales.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año
traffic_city_year_2024 =(traffic
                        .groupby(["city", "country", "year"], as_index=False)
                        .agg({
                        "jams_delay": "mean",
                        "traffic_index_live": "mean",
                        "jams_length_in_kms": "mean",
                        "jams_count": "mean",
                        "mins_delay": "mean",
                        "travel_time_live_per_10_kms_mins": "mean",
                        "travel_time_historic_per_10_kms_mins": "mean"
    })
)

# Mostrar resultado
traffic_city_year_2024.head()

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
# tu código aquí
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es Ciudad de Mexico

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo con el cálculo de los promedios de tráfico agrupando por ciudad, país y año, lo que demuestra un buen manejo de `groupby` y `agg` para análisis agregados. Es clave la selección de variables relevantes y el uso de `as_index=False`, que facilita la manipulación posterior del resultado.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_in_kms','jams_count','mins_delay',
             'travel_time_live_per_10_kms_mins','travel_time_historic_per_10_kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm','population_m']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

# Unir datasets
merged = pd.merge(traffic_2024_small, eco_2024_small, on=["city","year"], how="inner")

# Mostrar las primeras 5 filas
print(merged.head(5))

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has logrado seleccionar de manera adecuada las columnas clave de ambos conjuntos de datos y reducirlos correctamente antes de la unión.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico


merged["jams_delay"].plot(kind="box")

# obtener promedio para mostrarlo en título
mean_value = merged['jams_delay'].mean()
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.show()

# %%
# Columnas para el dataset de tráfico
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_in_kms','jams_count','mins_delay',
             'travel_time_live_per_10_kms_mins','travel_time_historic_per_10_kms_mins']

# Columnas para el dataset económico (nombres CORRECTOS)
right_cols = ['year','city','country','city_gdp_capita','unemployment_pct','pm','population_m']

# Crear los DataFrames pequeños
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

# Hacer el merge (ahora ambos tienen 'city' con el mismo nombre)
merged = pd.merge(traffic_2024_small, eco_2024_small, on=["city","year"], how="inner")

# Verificar el resultado
print("¡Merge exitoso!")
print(f"Forma del DataFrame merged: {merged.shape}")
print(f"Columnas: {merged.columns.tolist()}")
print(f"Primeras 3 filas:")
print(merged.head(3))

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)
#Histograma → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
plt.hist(merged["city_gdp_capita"],bins=30)
plt.title("distribución de la economía")
plt.xlabel("distribución")
plt.ylabel("valor promedio ")
plt.show

# %%
# Gráfico de barras para comparar jams_delay y city_gdp_capita por ciudad

# Importar las librerías necesarias
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Normalizar ambas variables a la misma escala (0-100)
scaler = MinMaxScaler(feature_range=(0, 100))
merged['jams_delay_norm'] = scaler.fit_transform(merged[['jams_delay']])
merged['gdp_capita_norm'] = scaler.fit_transform(merged[['city_gdp_capita']])

# Crear el gráfico de barras con datos normalizados
merged.plot(x='city', y=['jams_delay_norm', 'gdp_capita_norm'], kind='bar')
plt.title('Comparación: Congestión vs PIB per cápita (Normalizado 0-100)')
plt.ylabel('Valores normalizados (0-100)')
plt.xlabel('Ciudades')
plt.xticks(rotation=90)
plt.legend(['Retrasos por congestión', 'PIB per cápita'])
plt.tight_layout()  # Para que no se corten las etiquetas
plt.show()

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
#     No se observa una relación clara entre el PIB per cápita y los niveles de congestión. Aunque algunas ciudades con economías relevantes como Ciudad de México, Bogotá y São Paulo presentan altos niveles de retraso por congestión, esto no parece estar directamente asociado a su PIB per cápita, sino a otros factores como densidad poblacional, infraestructura vial o volumen de tráfico.
#
# * ¿O sucede lo contrario, o no existe una relación clara?
#
#   En general, no existe una relación consistente entre ambas variables. Por ejemplo, ciudades como Belo Horizonte muestran un PIB per cápita relativamente alto sin presentar niveles de congestión proporcionalmente elevados, lo que refuerza la idea de que el PIB per cápita no es un predictor directo del tráfico urbano.

# %% [markdown]
# Escribe tus comentarios:

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
#
# Has desarrollado correctamente la visualización exploratoria al crear el boxplot de *jams_delay*, incorporando además el valor promedio en el título, lo que aporta una interpretación clara del comportamiento de la congestión. También realizaste la normalización de variables antes de compararlas en el gráfico de barras, lo cual demuestra comprensión del problema de escalas.
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Empleas una repetición innecesaria del proceso de selección y *merge* de los datasets que podría simplificarse reutilizando el dataframe ya creado.
#
# </div>
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %%
# Conteo de valores faltantes
#missing_count = merged.isnull().sum()

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
#
# **Contexto & objetivo:**
#
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
#
# En términos generales, el análisis sugiere que existe una relación parcial entre la movilidad urbana y el PIB per cápita, especialmente en ciudades capitales o centros económicos relevantes. En estas ciudades, que concentran una mayor actividad económica y generación de ingresos, se observa una tendencia a mayores niveles de congestión y demoras en la movilidad urbana. Casos como Ciudad de México, Bogotá y São Paulo muestran una relación cercana entre altos niveles de actividad económica y mayores retrasos por congestión.
#
# No obstante, esta relación no es completamente lineal ni universal, lo que indica que la movilidad urbana está influenciada por múltiples factores adicionales, como la infraestructura de transporte, la planificación urbana y la densidad poblacional.
#
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
#
# Para llegar a esta conclusión, se analizaron las siguientes variables:
#
# - PIB per cápita (city_gdp_capita): indicador de productividad económica y nivel de ingreso promedio por ciudad.
#
# - Retrasos por congestión (jams_delay, mins_delay): reflejan el impacto del tráfico en los tiempos de desplazamiento.
#
# - Tiempos de viaje (travel_time_live_per_10kms_mins): permiten evaluar la eficiencia de la movilidad urbana.
#
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
#
#     El análisis se centró específicamente en el año 2024 e incluyó información correspondiente a 15 ciudades distribuidas en 7 países. Esta cobertura permite realizar comparaciones entre distintos contextos urbanos y económicos dentro de la región, manteniendo un enfoque consistente en un mismo periodo temporal.
#
#
#
#
# **Metodología (alto nivel):**
#
# El análisis comenzó con un proceso de limpieza y estandarización de datos, en el cual se unificaron los nombres de las columnas utilizando el formato snake_case, sin mayúsculas, para garantizar consistencia. Además, se corrigieron formatos de datos y se eliminaron símbolos innecesarios para unificar valores. Columnas temporales como update_time_utc fueron convertidas a tipo datetime, lo que permitió crear la variable year, filtrar por año y asegurar una correcta integración entre datasets.
#
# Posteriormente, se seleccionaron únicamente las columnas más relevantes de cada conjunto de datos y se agregaron las métricas de tráfico a nivel ciudad–año. Para integrar la información económica, se realizó una unión INNER utilizando city y year como claves, generando el dataset final denominado merged, que contiene solo las observaciones presentes en ambos datasets.
#
# Finalmente, se realizaron validaciones visuales exploratorias, incluyendo el análisis de distribuciones, la identificación de valores atípicos mediante boxplots y la observación de tendencias generales. Estas visualizaciones permitieron evaluar la calidad de los datos y apoyar la interpretación de la relación entre movilidad urbana y productividad económica
#
#
#
#
# **Hallazgos iniciales:**
#
# El gráfico comparativo entre retrasos por congestión y PIB per cápita (ambos normalizados en una escala 0–100) muestra que no existe una relación lineal directa entre ambas variables para todas las ciudades analizadas. Sin embargo, se identifican patrones claros y contrastes relevantes.
#
# - Ciudad de México destaca como el caso más evidente: presenta el nivel más alto de congestión del conjunto, acompañado de un PIB per cápita relativamente alto, lo que sugiere que la actividad económica intensa genera una fuerte presión sobre la movilidad urbana.
#
# - Bogotá y São Paulo muestran una combinación de congestión elevada con PIB per cápita medio, lo que indica posibles ineficiencias en la movilidad que podrían estar limitando el aprovechamiento pleno de su actividad económica.
#
# - Buenos Aires presenta un PIB per cápita alto con niveles de congestión moderados, lo que la diferencia de otras capitales y sugiere una mejor capacidad de absorción o mitigación del tráfico.
#
# - Ciudades como Belo Horizonte, Fortaleza y Recife muestran baja congestión y menor PIB per cápita, reflejando contextos urbanos menos presionados tanto económica como vialmente.
#
# *Anomalías y outliers*
#
# Ciudad de México actúa como un outlier en congestión, con valores significativamente más altos que el resto.
#
# Montevideo destaca por un PIB per cápita alto con congestión prácticamente nula, lo que la convierte en un caso atípico que podría requerir un análisis específico de políticas de movilidad e infraestructura.
#
# **Recomendaciones**
#
# Ciudad prioritaria para inversión en transporte:
#
# - Bogotá emerge como la ciudad más equilibrada entre alta congestión y PIB per cápita medio, lo que sugiere que mejoras en infraestructura de transporte podrían generar impactos directos en productividad y calidad de vida. A diferencia de Ciudad de México, donde la congestión es extrema pero el PIB es alto, Bogotá presenta mayor margen de ganancia relativa.
#
# *Ciudades para análisis complementario:*
#
# - São Paulo, por su alta congestión persistente.
#
# - Ciudad de México, por ser un outlier que requiere estrategias de gran escala.
#
# - Montevideo, como caso de referencia positiva para estudiar buenas prácticas.
#
# *Validación y profundización del análisis:*
#
# Incorporar variables adicionales como densidad poblacional, uso de transporte público e inversión histórica en movilidad permitiría explicar mejor las diferencias observadas entre ciudades con PIB similar pero niveles de congestión distintos.
#
# **¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?**
#
# Bogotá presenta la combinación más clara de alta congestión vehicular y PIB per cápita relativamente bajo, lo que la convierte en la ciudad prioritaria para inversión en infraestructura de transporte.
# Lima tiene congestión moderada y PIB bajo, pero la relación es menos evidente.
# Buenos Aires, aunque congestionada, tiene mayor PIB per cápita, situándola como prioridad secundaria.
#
# Conclusión: Bogotá es la ciudad que más cumple con el criterio de alta congestión y menor productividad económica.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis muestra una comprensión sólida de la relación entre movilidad urbana y productividad económica, ya que logras articular cómo la congestión no actúa de forma aislada, sino en interacción con factores estructurales de cada ciudad.
#
# La manera en que integras datos de tráfico y variables económicas evidencia criterio analítico al justificar por qué algunas capitales concentran tanto actividad económica como mayores tensiones en la movilidad, mientras que otras se apartan de ese patrón.
#
# Asimismo, el uso de comparaciones entre ciudades y la identificación de casos atípicos aportan profundidad interpretativa y evitan conclusiones simplistas, fortaleciendo la validez general del análisis.
#
#
#
#
# </div>
